# %% [markdown]
# **Assignment 2**
#
# Use the semantic chunking code in this notebook to chunk the documents for the naive rag we developed and analyze the performance for various queries
#
# Check with the following embedding models for semantic chunking and analyze the performance
#
#
# 1.   BAAI/bge-small-en-v1.5
# 2.   all-MiniLM-L6-v2
# 3.   sentence-transformers/all-MiniLM-L12-v2

# %%
# First, install required packages
# !pip install sentence-transformers numpy scikit-learn

import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import re
from typing import List, Tuple
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (4.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.51.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.31.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.13.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.4.26)

# %%
class SentenceTransformerChunker:
    def __init__(self, model_name='all-MiniLM-L6-v2', similarity_threshold=0.7):
        """
        Initialize the chunker with a SentenceTransformer model

        Args:
            model_name: Name of the sentence transformer model
            similarity_threshold: Threshold for semantic similarity
        """
        self.model = SentenceTransformer(model_name)
        self.similarity_threshold = similarity_threshold

    def split_into_sentences(self, text: str) -> List[str]:
        """Split text into sentences"""
        # Simple sentence splitting (you can use more sophisticated methods)
        sentences = re.split(r'[.!?]+', text)
        sentences = [s.strip() for s in sentences if s.strip()]
        return sentences

    def semantic_chunking(self, text: str, max_chunk_size: int = 5) -> List[str]:
        """
        Create chunks based on semantic similarity

        Args:
            text: Input text to chunk
            max_chunk_size: Maximum number of sentences per chunk

        Returns:
            List of text chunks
        """
        sentences = self.split_into_sentences(text)
        if not sentences:
            return []

        # Generate embeddings for all sentences
        embeddings = self.model.encode(sentences)

        chunks = []
        current_chunk = [sentences[0]]
        current_embedding = embeddings[0:1]

        for i in range(1, len(sentences)):
            # Calculate similarity with current chunk
            chunk_mean_embedding = np.mean(current_embedding, axis=0).reshape(1, -1)
            similarity = cosine_similarity(
                chunk_mean_embedding,
                embeddings[i:i+1]
            )[0][0]

            # If similar enough and chunk not too large, add to current chunk
            if (similarity >= self.similarity_threshold and
                len(current_chunk) < max_chunk_size):
                current_chunk.append(sentences[i])
                current_embedding = np.vstack([current_embedding, embeddings[i:i+1]])
            else:
                # Start new chunk
                chunks.append(' '.join(current_chunk))
                current_chunk = [sentences[i]]
                current_embedding = embeddings[i:i+1]

        # Add the last chunk
        if current_chunk:
            chunks.append(' '.join(current_chunk))

        return chunks

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 7.3 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
def main():
    # Sample text
    pdf_path = "/content/VITEEE-2024-information-brochure.pdf"

    sample_text = ""
    try:
        import PyPDF2
        with open(pdf_path, 'rb') as file:
            reader = PyPDF2.PdfReader(file)
            for page_num in range(len(reader.pages)):
                page = reader.pages[page_num]
                sample_text += page.extract_text()
    except FileNotFoundError:
        print(f"Error: The file {pdf_path} was not found.")
        return
    except Exception as e:
        print(f"An error occurred while reading the PDF: {e}")
        return

    # Initialize chunker
    chunker = SentenceTransformerChunker(similarity_threshold=0.6)

    # Perform semantic chunking
    chunks = chunker.semantic_chunking(sample_text, max_chunk_size=4)

    print("=== Semantic Chunks ===")
    for i, chunk in enumerate(chunks, 1):
        print(f"Chunk {i}:")
        print(chunk)
        print("-" * 50)


if __name__ == "__main__":
    main()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# === Semantic Chunks ===
# Chunk 1:
# /vituniversity /vellore_vit www vit
# --------------------------------------------------
# Chunk 2:
# ac
# --------------------------------------------------
# Chunk 3:
# in /vellore-institute-of-technology /VIT_univ
# 20242024
# VIT ENGINEERING ENTRANCE
# EXAMINATION
# VIT ENGINEERING ENTRANCE
# EXAMINATION
# For Admission to B
# --------------------------------------------------
# Chunk 4:
# T ech
# --------------------------------------------------
# Chunk 5:
# Programmes of
# VIT - Vellore | VIT - Chennai | VIT - AP | VIT - Bhopal
# For Admission to B
# --------------------------------------------------
# Chunk 6:
# T ech
# --------------------------------------------------
# Chunk 7:
# Programmes of
# VIT - Vellore | VIT - Chennai | VIT - AP | VIT - BhopalciogNg caHT jUk
# VELLORE INSTITUTE OF TECHNOLOGYVITVIT
# Vellore Institute of Technology
# (Deemed to be University under section 3 of UGC Act, 1956)R
# VITEEE
# ProspectusVIT - VelloreVIT - Chennai
# VIT - APVIT - Bhopal
# 1
# --------------------------------------------------
# Chunk 8:
# About VIT
# 2
# --------------------------------------------------
# Chunk 9:
# B
# --------------------------------------------------
# Chunk 10:
# Tech Programmes Oﬀered
# 3
# --------------------------------------------------
# Chunk 11:
# Online Application Form
# 4
# --------------------------------------------------
# Chunk 12:
# Eligibility Criteria
# 5
# --------------------------------------------------
# Chunk 13:
# Admission Process
# 6
# --------------------------------------------------
# Chunk 14:
# About VITEEE
# 6
# --------------------------------------------------
# Chunk 15:
# 1    Test Cities
# 7
# --------------------------------------------------
# Chunk 16:
# Selection Criteria
# 8
# --------------------------------------------------
# Chunk 17:
# Counselling Process
# 9
# --------------------------------------------------
# Chunk 18:
# Admission Process for Candidates under NRI Category
# 10
# --------------------------------------------------
# Chunk 19:
# Document Submission
# 11
# --------------------------------------------------
# Chunk 20:
# Scholarship
# 12
# --------------------------------------------------
# Chunk 21:
# Fee Structure
# 13
# --------------------------------------------------
# Chunk 22:
# Withdrawal Procedure
# 14
# --------------------------------------------------
# Chunk 23:
# Refund Policy
# 15
# --------------------------------------------------
# Chunk 24:
# Campus life
# 16
# --------------------------------------------------
# Chunk 25:
# Hostels
# 17
# --------------------------------------------------
# Chunk 26:
# Anti ragging committee
# 18
# --------------------------------------------------
# Chunk 27:
# Important Dates01
# 01
# 03
# 05
# 07
# 07
# 08
# 09
# 09
# 10
# 11
# 11
# 12
# 13
# 13
# 14
# 14
# 15
# 15Contents
#  VIT (Vellore Institute of Technology), established in 1984, was conferred with the status of a deemed university in 2001 by the Govern-
# ment of India
# --------------------------------------------------
# Chunk 28:
# In three decades, the Institution has emerged as an innovator in higher education, growing from 180 students to 67,000+
# students
# --------------------------------------------------
# Chunk 29:
# Today, it is counted among the most prominent and respected universities in India, featuring top-ranked academic
# programmes
# --------------------------------------------------
# Chunk 30:
# The main campus of VIT is at Vellore
# --------------------------------------------------
# Chunk 31:
# It started another campus in Chennai subsequently VIT - AP at Amaravati and VIT -
# Bhopal at Madhya Pradesh were started as State Private Universities later
# --------------------------------------------------
# Chunk 32:
# Eco-friendly in design and equipped with cutting-edge
# infrastructure, VIT provides a favorable atmosphere for learning and living
# --------------------------------------------------
# Chunk 33:
# Quality in teaching-learning, research, and innovation are at
# the core of education at VIT The institution follows a student-centered culture and places the highest importance on quality and consis -
# tency in learning, teaching, and research experiences
# --------------------------------------------------
# Chunk 34:
# About VIT 1
# --------------------------------------------------
# Chunk 35:
# B
# --------------------------------------------------
# Chunk 36:
# Tech - Aerospace Engineering
# Vellore Chennai AP BhopalB Tech - Biotechnology
# Vellore Chennai AP Bhopal
# B Tech - Bioengineering
# Vellore Chennai AP BhopalB Tech - Chemical Engineering
# Vellore Chennai AP Bhopal
# B
# --------------------------------------------------
# Chunk 37:
# Tech - Civil Engineering
# Vellore Chennai AP Bhopal Vellore Chennai AP Bhopal
# Vellore Chennai AP Bhopal Vellore Chennai AP Bhopal
# Vellore Chennai AP Bhopal
# Vellore Chennai AP BhopalVellore Chennai AP Bhopal
# Vellore Chennai AP BhopalVellore Chennai AP Bhopal
# Vellore Chennai AP BhopalVellore Chennai AP Bhopal
# Vellore Chennai AP BhopalVellore Chennai AP Bhopal
# Vellore Chennai AP BhopalB
# --------------------------------------------------
# Chunk 38:
# Tech - Computer Science and Engineering
# (Artiﬁcial Intelligence and Robotics)
# B Tech - Computer Science & Engineering
# (Cyber Security & Digital Forensics)B Tech - Computer Science and Engineering
# (Health Informatics)
# B Tech - Computer Science & Engineering
# (Cloud Computing & Automation)B
# --------------------------------------------------
# Chunk 39:
# Tech - Computer Science and Engineering
# (Bioinformatics)
# B Tech - Computer Science and Engineering and
# Business systems (in collaboration with TCS)B Tech - Computer Science and Engineering
# (Information Security)
# B Tech - Computer Science and Engineering
# and Business SystemsB
# --------------------------------------------------
# Chunk 40:
# Tech - Computer Science and Engineering
# (Data Science)
# B Tech - Computer Science and Engineering
# (Internet of Things)B Tech - Computer Science and Engineering
# (Cyber Physical Systems)B Tech - Computer Science and Engineering
# B
# --------------------------------------------------
# Chunk 41:
# Tech - Computer Science and Engineering
# (Block Chain Technology)01
# 03
# 05
# 07
# 10
# 12
# 14
# 1602
# 04
# 06
# 08
# 09
# 11
# 13
# 15
# 17 18
# 2
# --------------------------------------------------
# Chunk 42:
# B
# --------------------------------------------------
# Chunk 43:
# Tech
# --------------------------------------------------
# Chunk 44:
# Programmes Oﬀered
# 1Vellore Chennai AP BhopalB
# --------------------------------------------------
# Chunk 45:
# Tech - Computer Science & Engineering
# (Gaming Technology)
# Vellore Chennai AP BhopalVellore Chennai AP Bhopal
# Vellore Chennai AP Bhopal Vellore Chennai AP Bhopal
# Vellore Chennai AP Bhopal Vellore Chennai AP Bhopal
# Vellore Chennai AP BhopalVellore Chennai AP Bhopal
# Vellore Chennai AP BhopalB
# --------------------------------------------------
# Chunk 46:
# Tech - Electronics and Instrumentation
# Engineering
# B Tech - Electronics and Computer EngineeringB Tech - Electrical and Computer Science
# Engineering
# B
# --------------------------------------------------
# Chunk 47:
# Tech - Fashion TechnologyVellore Chennai AP Bhopal
# Vellore Chennai AP Bhopal
# Vellore Chennai AP Bhopal Vellore Chennai AP Bhopal
# Vellore Chennai AP BhopalVellore Chennai AP BhopalB
# --------------------------------------------------
# Chunk 48:
# Tech - Computer Science & Engineering
# (E-Commerce Technology)
# B Tech - Electronics & Communication
# Engineering (Artiﬁcial Intelligence & Cybernetics)B Tech - Electronics Engineering
# (VLSI Design and Technology)
# B Tech - Electrical and Electronics EngineeringB
# --------------------------------------------------
# Chunk 49:
# Tech - Electronics & Communication
# Engineering
# B Tech - Electronics and Communication
# Engineering (Biomedical Engineering)
# B Tech - Mechanical Engineering
# (Artiﬁcial Intelligence & Robotics)B Tech - Information TechnologyB
# --------------------------------------------------
# Chunk 50:
# Tech - Computer Science and Engineering
# (Cyber Security)
# B
# --------------------------------------------------
# Chunk 51:
# Tech - Mechanical Engineering
# Vellore Chennai AP BhopalVellore Chennai AP Bhopal
# B
# --------------------------------------------------
# Chunk 52:
# Tech - Mechatronics and AutomationB
# --------------------------------------------------
# Chunk 53:
# Tech - Computer Science & Engineering
# (Education Technology)
# B
# --------------------------------------------------
# Chunk 54:
# Tech - Mechanical(Manufacturing Engineering)19 20
# 21
# Vellore Chennai AP BhopalB
# --------------------------------------------------
# Chunk 55:
# Tech - Computer Science and Engineering
# (Blockchain)23
# 28
# Vellore Chennai AP BhopalB
# --------------------------------------------------
# Chunk 56:
# Tech - Electronics and Communication
# Engineering (Embedded Systems)30
# Vellore Chennai AP BhopalB Tech - Electronics and Communication
# Engineering (VLSI)3127
# 3229
# 3433
# 36 35
# 38 37
# 3924
# Vellore Chennai AP BhopalB Tech - Computer Science and Engineering
# (Software Engineering)
# Vellore Chennai AP BhopalB Tech - Computer Science and Engineering
# (Data Analytics)25 26
# 40
# 4543
# Vellore Chennai AP BhopalB
# --------------------------------------------------
# Chunk 57:
# Tech - Mechanical Engineering
# (Electric Vehicles)Vellore Chennai AP BhopalB Tech - Mechanical Engineering
# (Automotive Design)
# 4441
# Vellore Chennai AP BhopalB
# --------------------------------------------------
# Chunk 58:
# Tech - Mechanical Engineering
# (Robotics)42
# 2Visit https://vitap
# --------------------------------------------------
# Chunk 59:
# ac
# --------------------------------------------------
# Chunk 60:
# in/btech/ for full list of specialisation / Minor / Double Major optionsVellore Chennai AP BhopalB
# --------------------------------------------------
# Chunk 61:
# Tech - Computer Science & Engineering
# (Artiﬁcial Intelligence & Machine Learning)223
# --------------------------------------------------
# Chunk 62:
# 1
# --------------------------------------------------
# Chunk 63:
# Guidelines for ﬁlling up the application form
# The B
# --------------------------------------------------
# Chunk 64:
# Tech Admission Application Form is available online at www
# --------------------------------------------------
# Chunk 65:
# viteee vit
# --------------------------------------------------
# Chunk 66:
# ac
# --------------------------------------------------
# Chunk 67:
# in
# --------------------------------------------------
# Chunk 68:
# The Cost of the Application Form is Rs
# --------------------------------------------------
# Chunk 69:
# 1,350 /-
# (Non-Refundable)
# --------------------------------------------------
# Chunk 70:
# Valid e-mail address and active mobile number are required
# --------------------------------------------------
# Chunk 71:
# Enter all the relevant details carefully
# --------------------------------------------------
# Chunk 72:
# An OTP will be sent to your Registered Indian Mobile Number for veriﬁcation Once OTP is validated, a password will be sent to your registered email address
# --------------------------------------------------
# Chunk 73:
# All the correspondence shall be made to the registered email address and mobile number
# only
# --------------------------------------------------
# Chunk 74:
# 3 1 1
# --------------------------------------------------
# Chunk 75:
# New User Registration
# Valid e-mail address and active mobile number are required
# --------------------------------------------------
# Chunk 76:
# 3 1 2
# --------------------------------------------------
# Chunk 77:
# Sign-in for Registered Users
# Fill in the relevant ﬁelds carefully
# --------------------------------------------------
# Chunk 78:
# An Application Number will be generated after ﬁlling
# primary details Refer this application number in all your future correspondence
# --------------------------------------------------
# Chunk 79:
# 3 1 3
# --------------------------------------------------
# Chunk 80:
# Filling online application form
# Application cost of Rs
# --------------------------------------------------
# Chunk 81:
# 1350 should be paid through Net Banking Account/ Credit/
# Debit Card/ Paytm
# For Abroad test centre : Equivalent to USD 90 in INR
# Note : Application cost is non-refundable3
# --------------------------------------------------
# Chunk 82:
# 1 4
# --------------------------------------------------
# Chunk 83:
# Payment
# Step
# 04Step
# 03Step
# 02Step
# 013
# --------------------------------------------------
# Chunk 84:
# Online Application Form
# 3The photograph must be taken against a light background
# --------------------------------------------------
# Chunk 85:
# Only White/oﬀ-white
# background is preferred
# --------------------------------------------------
# Chunk 86:
# The photograph must show the full frontal view without tilting of face, both ears visible,
# open eyes with neutral expression
# --------------------------------------------------
# Chunk 87:
# Make sure there is no glare from spectacles and no blur in the focus
# --------------------------------------------------
# Chunk 88:
# The ﬁle should be only in JPEG format
# --------------------------------------------------
# Chunk 89:
# The ﬁle size of the photograph should be within 20 kB to 300 kB The photograph dimension should be of Width(300 to 400 pixels) X Height (400 to 550
# pixels)
# --------------------------------------------------
# Chunk 90:
# The photograph should not be too dark or too bright but should have optimum exposure
# --------------------------------------------------
# Chunk 91:
# The photograph should have only one face
# --------------------------------------------------
# Chunk 92:
# Please draw a rectangular box of size 6 cm (width) X 2 cm (height) on a A4 white paper
# --------------------------------------------------
# Chunk 93:
# Sign
# with dark blue or black pen within the box
# --------------------------------------------------
# Chunk 94:
# Scan the signature in (
# --------------------------------------------------
# Chunk 95:
# jpeg) format using scanner and crop the image
# --------------------------------------------------
# Chunk 96:
# You can open the scanned signature image with MS Paint and crop the image at the
# particular rectangular box which was already marked and signed on the A4 white paper
# --------------------------------------------------
# Chunk 97:
# While cropping the image make sure that the dimension should be 3
# --------------------------------------------------
# Chunk 98:
# 5 cm (width) X 1 5 cm
# (height)
# --------------------------------------------------
# Chunk 99:
# The scanned signature image size should be within 20 kB to 300 kB
# --------------------------------------------------
# Chunk 100:
# The photograph must be in color and should be taken professionally in a studio with the
# following speciﬁcations:3
# --------------------------------------------------
# Chunk 101:
# 1 5
# --------------------------------------------------
# Chunk 102:
# Photo and Signature Upload
# 3
# --------------------------------------------------
# Chunk 103:
# 1 6
# --------------------------------------------------
# Chunk 104:
# Download ﬁlled-in application form
# Download and save the ﬁlled-in application for your reference and further
# correspondence
# --------------------------------------------------
# Chunk 105:
# Applicants NEED NOT SEND hard copy of the ﬁlled-in application form to VIT
# --------------------------------------------------
# Chunk 106:
# Signature uploading procedure:
# Step
# 05
# Step
# 06
# 44
# --------------------------------------------------
# Chunk 107:
# 1
# --------------------------------------------------
# Chunk 108:
# Nationality
# The applicant should be a Resident / Non-Resident Indian National / PIO / OCI
# --------------------------------------------------
# Chunk 109:
# NRI applicants can directly apply under 'NRI Category' through NRI application form
# --------------------------------------------------
# Chunk 110:
# Foreign applicants who studied/studying abroad can apply directly through the International application
# form
# --------------------------------------------------
# Chunk 111:
# (https://vit
# --------------------------------------------------
# Chunk 112:
# ac
# --------------------------------------------------
# Chunk 113:
# in/admissions/international/overview)
# Applicants whose date of birth falls on or after 1st July 2002 are eligible to apply for engineering admission
# 2024
# --------------------------------------------------
# Chunk 114:
# The date of birth as recorded in the High School / SSC / X Certiﬁcate will be considered authentic
# --------------------------------------------------
# Chunk 115:
# Applicants should produce this certiﬁcate in original as proof of their age at the time of
# counselling/admission, failing which their candidacy for admission will be disqualiﬁed
# --------------------------------------------------
# Chunk 116:
# 4 2
# --------------------------------------------------
# Chunk 117:
# Age Limit
# 4
# --------------------------------------------------
# Chunk 118:
# 3
# --------------------------------------------------
# Chunk 119:
# Qualifying Examination
# The ﬁnal examination of the 10+2 system of higher secondary examination conducted by the State Board;
# Central Board of Secondary Education (CBSE, New Delhi), The Council for Indian School Certiﬁcate
# Examination (ISCE),New Delhi
# --------------------------------------------------
# Chunk 120:
# Intermediate or Two-year Pre-University Examination conducted by a recognized Board/ University
# --------------------------------------------------
# Chunk 121:
# High School Certiﬁcate Examination of the Cambridge University or International Baccalaureate Diploma of
# the International Baccalaureate Oﬃce, Geneva
# --------------------------------------------------
# Chunk 122:
# (Physics & Mathematics - HL, Chemistry - SL)
# General Certiﬁcate Education (GCE) examination (London/Cambridge/Srilanka) at the Advanced (A) level
# --------------------------------------------------
# Chunk 123:
# Regular 'NIOS' board candidates are also eligible for Undergraduate Engineering programmes
# --------------------------------------------------
# Chunk 124:
# Applicants
# should produce the Migration Cum Transfer Certiﬁcate at the time of joining
# --------------------------------------------------
# Chunk 125:
# Applicants who have completed the Class 12 (or equivalent) examination outside India or from a Board not
# speciﬁed above should produce a certiﬁcate from the Association of Indian Universities (AIU) to the eﬀect
# that the examination they have passed is equivalent to the Class 12 Examination with grade/CGPA converted
# to percentage
# --------------------------------------------------
# Chunk 126:
# Applicants applying for UG Engineering admission should have either completed or shall be appearing in
# 2024, in any one of the following qualifying examinations:
# For Indian nationals attending VITEEE 2024 is mandatory to be eligible for B
# --------------------------------------------------
# Chunk 127:
# Tech
# --------------------------------------------------
# Chunk 128:
# admission
# --------------------------------------------------
# Chunk 129:
# In case VITEEE 2024 gets cancelled due to natural calamities, qualifying criteria may be substituted with higher
# secondary marks or JEE-24 or a valid SAT
# --------------------------------------------------
# Chunk 130:
# Applicants will be informed with speciﬁcs in such case
# --------------------------------------------------
# Chunk 131:
# 4
# --------------------------------------------------
# Chunk 132:
# Eligibility Criteria
# 4
# --------------------------------------------------
# Chunk 133:
# 1 1 4 1
# --------------------------------------------------
# Chunk 134:
# 2 4 1 3
# --------------------------------------------------
# Chunk 135:
# 4 2 1 4
# --------------------------------------------------
# Chunk 136:
# 2 2 4 2
# --------------------------------------------------
# Chunk 137:
# 3 4 3 1
# --------------------------------------------------
# Chunk 138:
# 4 3 2 4
# --------------------------------------------------
# Chunk 139:
# 3 3 4 3
# --------------------------------------------------
# Chunk 140:
# 4 4 3 5
# --------------------------------------------------
# Chunk 141:
# 4 3 6
# --------------------------------------------------
# Chunk 142:
# 5Applicants applying for the Undergraduate Engineering admission in 2024 should have secured minimum
# aggregate of 60% in Physics, Chemistry, and Mathematics/Biology (PCM/PCB/PCMB) in the qualifying examination
# (+2/Intermediate) Applicants applying for the Undergraduate Engineering admission in 2024 should have passed with minimum
# aggregate of 50% in Physics, Chemistry, and Mathematics/Biology in the qualifying examination (+2/Intermediate)
# for the following categories:
#  Applicants belonging to SC/ST
#  Applicants hailing from Jammu and Kashmir/ Ladakh and the Northeastern states of Arunachal Pradesh,
# Assam, Manipur, Meghalaya, Mizoram, Nagaland, Sikkim and Tripura
# --------------------------------------------------
# Chunk 143:
# Certiﬁcate to prove community / nativity
# should be produced at the time of counselling, failing which they will not be considered for admission
# --------------------------------------------------
# Chunk 144:
# PCMB/PCM applicants who have attempted Mathematics, Physics, Chemistry, English and Aptitude (MPCEA) in
# VITEEE 2024 are eligible for all B
# --------------------------------------------------
# Chunk 145:
# Tech Programmes
# --------------------------------------------------
# Chunk 146:
# PCMB/PCB applicants who have attempted Biology, Physics, Chemistry, English and Aptitude (BPCEA) in VITEEE
# 2024 & PCB applicants who have attempted Mathematics, Physics, Chemistry, English and Aptitude (MPCEA) in
# VITEEE 2024 are eligible only for the following programmes :4
# --------------------------------------------------
# Chunk 147:
# 4
# --------------------------------------------------
# Chunk 148:
# Requirement of Qualifying Examination
# B
# --------------------------------------------------
# Chunk 149:
# Tech
# --------------------------------------------------
# Chunk 150:
# Biotechnology (VIT, Vellore)
# B
# --------------------------------------------------
# Chunk 151:
# Tech
# --------------------------------------------------
# Chunk 152:
# Computer Science and Engineering (Bioinformatics), (VIT - Vellore)
# B
# --------------------------------------------------
# Chunk 153:
# Tech
# --------------------------------------------------
# Chunk 154:
# Electronics and Communication Engineering (Biomedical Engineering), (VIT - Vellore)
# B
# --------------------------------------------------
# Chunk 155:
# Tech
# --------------------------------------------------
# Chunk 156:
# Bioengineering (VIT - Bhopal)
# B
# --------------------------------------------------
# Chunk 157:
# Tech
# --------------------------------------------------
# Chunk 158:
# Computer Science and Engineering (Health Informatics), (VIT - Bhopal)
# 4
# --------------------------------------------------
# Chunk 159:
# 4 1 4 4
# --------------------------------------------------
# Chunk 160:
# 2 4 5 1
# --------------------------------------------------
# Chunk 161:
# 4 5 2 1
# --------------------------------------------------
# Chunk 162:
# 2 3 4 5
# --------------------------------------------------
# Chunk 163:
# 4 5
# --------------------------------------------------
# Chunk 164:
# Subject Eligibility
# 6Submission of VITEEE
# Application through
# Web by
# applicants
# https://viteee
# --------------------------------------------------
# Chunk 165:
# vit
# --------------------------------------------------
# Chunk 166:
# ac
# --------------------------------------------------
# Chunk 167:
# in
# Generate link for
# test slot booking
# to the candidatesApplication
# Veriﬁcation
# &
# Scrutiny
# Appear for
# VITEEE 2024
# Announcement of
# Online Counselling
# based on
# VITEEE 2024 RankTest Slot,
# Centre booking &
# Admit Card
# Generation
# by the candidates
# VITEEE 2024
# Result
# Announcement
# Provisional
# Admission Letter
# to B
# --------------------------------------------------
# Chunk 168:
# Tech Programme
# based on Merit after
# required fee payment Document
# VeriﬁcationProgramme wishlist
# by the candidates
#  Vellore Institute of Technology Engineering Entrance Examination (VITEEE) is conducted for admission to undergraduate
# engineering programmes in VIT group of Institutions
# --------------------------------------------------
# Chunk 169:
# VITEEE will be conducted between 19 and 30 April 2024 (Tentative) at designat-
# ed centres across India and abroad (No
# --------------------------------------------------
# Chunk 170:
# of days will vary for test cities)
# --------------------------------------------------
# Chunk 171:
# The duration of the examination will be 2 hours and 30
# minutes
# --------------------------------------------------
# Chunk 172:
# Candidates can appear only once for VITEEE
# --------------------------------------------------
# Chunk 173:
# All questions will be Multiple Choice Questions and one mark for the right
# answer and zero for the wrong answer
# --------------------------------------------------
# Chunk 174:
# There will be a total of 125 questions divided into the section Maths/Biology (40 questions),
# Physics (35 questions), Chemistry (35 questions), Aptitude (10 questions), and English (5 questions)
# --------------------------------------------------
# Chunk 175:
# The question paper will be in
# English only
# --------------------------------------------------
# Chunk 176:
# The fee towards application and subsequent counselling is non-refundable
# --------------------------------------------------
# Chunk 177:
# The detailed syllabus is available at www
# --------------------------------------------------
# Chunk 178:
# vi-
# teee vit
# --------------------------------------------------
# Chunk 179:
# ac
# --------------------------------------------------
# Chunk 180:
# in
# --------------------------------------------------
# Chunk 181:
# The method of Equi-percentile is adopted for the merit list preparation of VITEEE-Computer Based Examination
# --------------------------------------------------
# Chunk 182:
# 6
# --------------------------------------------------
# Chunk 183:
# About VITEEE5
# --------------------------------------------------
# Chunk 184:
# Admission Process
# 7
# 01
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 1002Imphal
# Aizawl
# Agartala
# Shillong
# Amaravati(AP) | Ananthapur | Eluru | Kurnool | Nellore
# Rajahmundry | Srikakulam | Tanuku | Tirupati | VishakapatnamAhmedabad | Rajkot | Surat
# Vadodara | JamnagarFaridabad | Gurgaon | Hissar
# KurukshetraDharmasala | ShimlaJammu | Srinagar
# Bengaluru | Hubli | Mangalore | Mysuru
# Kochi | Kozhikode | Thiruvananthapuram
# ThrissurAmaravati | Aurangabad | Latur | Mumbai
# Nagpur | Nashik | Pune | Solapur | Thane
# Assagao
# Puducherry Amrister | Bathinda | Jalandhar City
# Ludhiana
# Ajmer | Bikaner | Jaipur
# Jodhpur | Kota | Udaipur
# Hyderabad | Karim Nagar | Khammam
# Mahbubnagar | Nalgonda | Warangal
# Chennai | Coimbatore | Erode | Kancheepuram | Kumbakonam
# Madurai | Nagarcoil | Salem | Tiruchirapalli | Tirunelveli | VelloreChandigarh
# Delhi
# Bhopal | Gwalior | JabalpurJAMMU & KASHMIR
# HIMACHAL PRADESH
# PUNJAB
# CHANDIGARH
# HARYANA
# DELHI
# RAJASTHAN
# MADHYA PRADESH
# GUJARAT
# MAHARASHTRA
# GOA
# KARNATAKA
# KERALA
# TELANGANA
# TAMILNADU
# PUDUCHERRY
# ANDHRA PRADESHPort BlairItanagar
# Dibrugar
# Guwahati | Silchar
# Bokaro | Dhanbad
# Jamshedpur | RanchiDimapur
# Berhampur
# Bhubaneswar | RourkelaGangtokDehradun | Pant Nagar | Roorkee
# Durgapur | Kolkata
# Siliguri
# Dubai | Kuwait | Muscat | Qatar | Kuala Lumpur | SingaporeAgra | Aligarh | Prayagraj | Bareilly | Ghaziabad | Gorakhpur | Jhansi | Kanpur | Lucknow
# Mathura | Meerut | Moradabad | Noida | Rae Bareli | Saharanpur | Varanasi
# Bhagalpur | Gaya | Muzaffarpur | Patna
# Bhilai | Bhilaspur | RaipurUTTARAKHAND
# UTTAR PRADESH
# BIHAR
# SIKKIM
# ARUNACHAL PRADESH
# ASSAM
# NAGALAND
# MANIPUR
# MIZORAM
# TRIPURA
# MEGHALAYA
# WEST BENGAL
# JHARKHAND
# ODISHA
# CHATTISGARH
# ANDAMAN & NICOBAR ISLANDS
# CENTRES ABROAD6
# --------------------------------------------------
# Chunk 185:
# 1
# --------------------------------------------------
# Chunk 186:
# Test Cities
# 8
# Selection is based on the rank secured through CBT (Computer Based Test) VITEEE 2024
# --------------------------------------------------
# Chunk 187:
# Selected candidates can participate in online counselling based on their ranking
# --------------------------------------------------
# Chunk 188:
# They can give options for speciﬁc
# campus, programme and category of fees
# --------------------------------------------------
# Chunk 189:
# Allotment will be based on the rank obtained, preference given and
# availability during online counselling Candidates with rank Upto 1 Lakh are eligible for counselling to all the four campuses, VIT - Vellore, VIT - Chennai, VIT -
# AP and VIT - Bhopal Rank holders above 1 lakh are eligible for counselling to VIT - AP and VIT - Bhopal campuses only
# --------------------------------------------------
# Chunk 190:
# VIT will verify the eligibility of candidates after completing the tuition fee payment on or before the stipulated date
# --------------------------------------------------
# Chunk 191:
# Candidates are required to produce documents on the day of reporting to the campus or as and when asked for, by the
# Oﬃce of Admissions
# --------------------------------------------------
# Chunk 192:
# Provisional Admission oﬀered during counselling will be valid ONLY if the eligibility is fulﬁlled
# --------------------------------------------------
# Chunk 193:
# The counselling process is common for VIT group of Institutions The online counselling will be held in ﬁve phases The
# rank, schedule, choice entry will be available in the counselling portal
# --------------------------------------------------
# Chunk 194:
# A non-refundable counselling fee of Rs
# --------------------------------------------------
# Chunk 195:
# 5,900/- is required to participate in the counselling process
# --------------------------------------------------
# Chunk 196:
# The applicants who fail to appear in their phase of counselling are eligible to appear in next phase, but limited to
# available choices in that phase
# --------------------------------------------------
# Chunk 197:
# Applicants may select campus / programme / fee category
# --------------------------------------------------
# Chunk 198:
# The allotment will be based on VITEEE Rank
# --------------------------------------------------
# Chunk 199:
# Once the
# required fee is paid, provisional admission letter will be available in portal
# --------------------------------------------------
# Chunk 200:
# Once allotted campus / programme / fee category cannot be changed
# --------------------------------------------------
# Chunk 201:
# 7 7 1 7
# --------------------------------------------------
# Chunk 202:
# 2 7 3 7
# --------------------------------------------------
# Chunk 203:
# 4 8 1 8
# --------------------------------------------------
# Chunk 204:
# 2 8 3 8
# --------------------------------------------------
# Chunk 205:
# 4 8 5
# --------------------------------------------------
# Chunk 206:
# Selection Criteria
# 8
# --------------------------------------------------
# Chunk 207:
# Online Counselling Process
# 9There is no Entrance Examination
# --------------------------------------------------
# Chunk 208:
# Admission is based on merit (marks/grades obtained in the
# qualifying examination-refer the                                 ) and availability of seats
# --------------------------------------------------
# Chunk 209:
# Interested NRI candidates can also apply through the given link : https://viteee
# --------------------------------------------------
# Chunk 210:
# vit
# --------------------------------------------------
# Chunk 211:
# ac
# --------------------------------------------------
# Chunk 212:
# in/Eligibility Norms
# Proof of Age & Nationality (Passport/Birth Certiﬁcate)
# 11th grade marksheet/AS Level/Form V(for appearing candidates) & 12th grade mark sheet/A Level/Form VI (for
# passed out candidates)
# Visa/Resident Card authenticating NRI status of parent
# Employer certiﬁcate (Optional at the time of application)
# On satisfying all the eligibility requirements, the branch allotment order will be e-mailed to the registered email
# id (candidates are requested to give valid email address of your parent)
# The provisional admission letter will be issued along with the fees structure
# --------------------------------------------------
# Chunk 213:
# (only if the students meet the
# eligibility requirements)
# Allotment of branch will be done on the basis of the application and documents received at our end
# Branch once allotted will not be changed under any circumstances
# Selected candidates are required to pay the Fees in USD as mentioned on the oﬀer letter9
# --------------------------------------------------
# Chunk 214:
# 1
# --------------------------------------------------
# Chunk 215:
# Scrutinizing the documents received from the candidate
# --------------------------------------------------
# Chunk 216:
# Step
# 02
# Step
# 03Step
# 01
# 9
# --------------------------------------------------
# Chunk 217:
# 2
# --------------------------------------------------
# Chunk 218:
# Issue of oﬀer letter
# 9
# --------------------------------------------------
# Chunk 219:
# 3
# --------------------------------------------------
# Chunk 220:
# Payment of Advance Fees
# Step
# 04 9
# --------------------------------------------------
# Chunk 221:
# 4
# --------------------------------------------------
# Chunk 222:
# Payment of Balance Fees
# Step
# 05 9
# --------------------------------------------------
# Chunk 223:
# 5
# --------------------------------------------------
# Chunk 224:
# Intimation on other Admission Formalities
# Step
# 069
# --------------------------------------------------
# Chunk 225:
# 6
# --------------------------------------------------
# Chunk 226:
# Payment of Hostel FeesNote: The ﬁlled-out application form along with necessary enclosures are to be duly uploaded along with the
# form The hostel fees should be paid seperately along with the tuition fees
# --------------------------------------------------
# Chunk 227:
# Refer the link below for the fee structure
# --------------------------------------------------
# Chunk 228:
# The candidate is requested to pay the balance Tuition fee as per the provisional admission letter along with the
# copy of the XII mark statement / website copy [if available ] / Copy of XII Hall Ticket or Admit card through Fund
# Transfer mode in USD
# --------------------------------------------------
# Chunk 229:
# On receipt of the balance fee, the details regarding the commencement of the programme and document
# submission will be intimated through email
# --------------------------------------------------
# Chunk 230:
# Candidates are requested to report to the University with the required original documents as per the provisional
# admission letter
# --------------------------------------------------
# Chunk 231:
# 9
# --------------------------------------------------
# Chunk 232:
# Admission Process for candidate under NRI Category
# VIT - Vellore VIT - Chennai VIT - Bhopal VIT - AP
# 10Copy of Provisional Letter
# XII Mark statements of all attempts of qualifying examination
# Transfer Certiﬁcate / School leaving Certiﬁcate
# Migration Certiﬁcate (if issued by the board)
# Student Proﬁle (https://admissions
# --------------------------------------------------
# Chunk 233:
# vit
# --------------------------------------------------
# Chunk 234:
# ac
# --------------------------------------------------
# Chunk 235:
# in/freshersportal/login) – (Signed by Student & Parent)
# Aﬃdavit by the Student (https://vit
# --------------------------------------------------
# Chunk 236:
# ac
# --------------------------------------------------
# Chunk 237:
# in/ﬁles/admissions/Aﬃdavit_Student
# --------------------------------------------------
# Chunk 238:
# pdf) – (Signed & Notarized)
# Aﬃdavit by the Parent (https://vit
# --------------------------------------------------
# Chunk 239:
# ac
# --------------------------------------------------
# Chunk 240:
# in/ﬁles/admissions/Aﬃdavit_Parent
# --------------------------------------------------
# Chunk 241:
# pdf) - (Signed & Notarized)
# Hostel Aﬃdavit (https://vit
# --------------------------------------------------
# Chunk 242:
# ac
# --------------------------------------------------
# Chunk 243:
# in/campuslife/hostels) - (Signed by Notarized)
# Certiﬁcate of Physical Fitness (https://vit
# --------------------------------------------------
# Chunk 244:
# ac
# --------------------------------------------------
# Chunk 245:
# in/ﬁles/admissions/PhysicalFitness_Certiﬁcate
# --------------------------------------------------
# Chunk 246:
# pdf)- (Certiﬁed by authorized
# Physician)
# Undertaking form (https://vit
# --------------------------------------------------
# Chunk 247:
# ac
# --------------------------------------------------
# Chunk 248:
# in/sites/default/ﬁles/Undertaking
# --------------------------------------------------
# Chunk 249:
# pdf) - (Signed by Student & Parent)
# Recent passport size colour photos – 2 Nos
# --------------------------------------------------
# Chunk 250:
# Aadhar card / Age proof certiﬁcate
# X & XII mark sheet
# Transfer Certiﬁcate/School Leaving Certiﬁcate
# Migration Certiﬁcate
# Community Certiﬁcate (For SC/ST only)
# Nativity Certiﬁcate (For candidates hailing from Jammu and Kashmir, Ladhak and the North Eastern states)
# Passport Copy (Student & Parent)
# Employer Certiﬁcate (original)
# Sponsorship letter (original)
# Note: All copies of documents will be archived and will not be returned for any reason
# --------------------------------------------------
# Chunk 251:
# Original Documents:
# Copy of documents (1 set) :
# Additional Documents required from NRI/Foreign students :
# *The Scholarship will be realized from second semester10
# --------------------------------------------------
# Chunk 252:
# Document Submission on Admission
# 11
# --------------------------------------------------
# Chunk 253:
# Scholarship*
# 11VITEEE rank holders of 1 to 10
# VITEEE rank holders of 11 to 50
# VITEEE rank holders of 51 to 100
# VITEEE rank holders of 101 to 50075% Tuition fee waiver for all
# the four years
# 50% Tuition fee waiver for all
# the four years
# 25% Tuition fee waiver for all
# the four years100% Tuition fee waiver for all
# the four yearsB
# --------------------------------------------------
# Chunk 254:
# TECH
# --------------------------------------------------
# Chunk 255:
# - Bioengineering
# B
# --------------------------------------------------
# Chunk 256:
# TECH
# --------------------------------------------------
# Chunk 257:
# - Biotechnology
# B
# --------------------------------------------------
# Chunk 258:
# TECH
# --------------------------------------------------
# Chunk 259:
# - Chemical Engineering
# B
# --------------------------------------------------
# Chunk 260:
# TECH
# --------------------------------------------------
# Chunk 261:
# - Civil EngineeringB
# --------------------------------------------------
# Chunk 262:
# TECH
# --------------------------------------------------
# Chunk 263:
# - Electrical and Electronics Engineering
# B
# --------------------------------------------------
# Chunk 264:
# TECH
# --------------------------------------------------
# Chunk 265:
# - Electronics and Instrumentation Engineering
# B
# --------------------------------------------------
# Chunk 266:
# TECH
# --------------------------------------------------
# Chunk 267:
# - Fashion Technology
# B
# --------------------------------------------------
# Chunk 268:
# TECH
# --------------------------------------------------
# Chunk 269:
# - Aerospace Engineering
# B
# --------------------------------------------------
# Chunk 270:
# TECH
# --------------------------------------------------
# Chunk 271:
# - Computer Science & Engineering (E-Commerce Technology)
# B
# --------------------------------------------------
# Chunk 272:
# TECH
# --------------------------------------------------
# Chunk 273:
# - Computer Science & Engineering (Education Technology)
# B
# --------------------------------------------------
# Chunk 274:
# TECH
# --------------------------------------------------
# Chunk 275:
# - Computer Science and Engineering and Business Systems
# B
# --------------------------------------------------
# Chunk 276:
# TECH
# --------------------------------------------------
# Chunk 277:
# - Computer Science and Engineering
# B
# --------------------------------------------------
# Chunk 278:
# TECH
# --------------------------------------------------
# Chunk 279:
# - Computer Science and Engineering (Artiﬁcial Intelligence and Machine Learning)
# B
# --------------------------------------------------
# Chunk 280:
# TECH
# --------------------------------------------------
# Chunk 281:
# - Computer Science and Engineering (Artiﬁcial Intelligence and Robotics)
# B
# --------------------------------------------------
# Chunk 282:
# TECH
# --------------------------------------------------
# Chunk 283:
# - Computer Science and Engineering (Bioinformatics)
# B
# --------------------------------------------------
# Chunk 284:
# TECH
# --------------------------------------------------
# Chunk 285:
# - Computer Science and Engineering (Block Chain Technology)
# B
# --------------------------------------------------
# Chunk 286:
# TECH
# --------------------------------------------------
# Chunk 287:
# - Computer Science and Engineering (Block Chain)
# B
# --------------------------------------------------
# Chunk 288:
# TECH
# --------------------------------------------------
# Chunk 289:
# - Computer Science and Engineering (Cyber Physical Systems)
# B
# --------------------------------------------------
# Chunk 290:
# TECH
# --------------------------------------------------
# Chunk 291:
# - Computer Science and Engineering (Cyber Security)
# B
# --------------------------------------------------
# Chunk 292:
# TECH
# --------------------------------------------------
# Chunk 293:
# - Computer Science and Engineering (Data Science)
# B
# --------------------------------------------------
# Chunk 294:
# TECH
# --------------------------------------------------
# Chunk 295:
# - Computer Science and Engineering (Data Analytics)
# B
# --------------------------------------------------
# Chunk 296:
# TECH
# --------------------------------------------------
# Chunk 297:
# - Computer Science and Engineering (Information Security)
# B
# --------------------------------------------------
# Chunk 298:
# TECH
# --------------------------------------------------
# Chunk 299:
# - Computer Science and Engineering (Internet of Things)
# B
# --------------------------------------------------
# Chunk 300:
# TECH
# --------------------------------------------------
# Chunk 301:
# - Computer Science & Engineering (Cloud Computing & Automation)
# B
# --------------------------------------------------
# Chunk 302:
# TECH
# --------------------------------------------------
# Chunk 303:
# - Computer Science & Engineering (Health Informatics)
# B
# --------------------------------------------------
# Chunk 304:
# TECH
# --------------------------------------------------
# Chunk 305:
# - Computer Science and Engineering and Business Systems (in collaboration with TCS)
# B
# --------------------------------------------------
# Chunk 306:
# TECH
# --------------------------------------------------
# Chunk 307:
# - Computer Science & Engineering (Cyber Security & Digital Forensics)
# B
# --------------------------------------------------
# Chunk 308:
# TECH
# --------------------------------------------------
# Chunk 309:
# - Computer Science & Engineering (Gaming Technology)
# B
# --------------------------------------------------
# Chunk 310:
# TECH
# --------------------------------------------------
# Chunk 311:
# - Computer Science and Engineering (Software Engineering)
# B
# --------------------------------------------------
# Chunk 312:
# TECH
# --------------------------------------------------
# Chunk 313:
# - Electrical and Computer Science Engineering
# B
# --------------------------------------------------
# Chunk 314:
# TECH
# --------------------------------------------------
# Chunk 315:
# - Electronics and Communication Engineering
# B
# --------------------------------------------------
# Chunk 316:
# TECH
# --------------------------------------------------
# Chunk 317:
# - Electronics and Communication Engineering (Biomedical Engineering)
# B
# --------------------------------------------------
# Chunk 318:
# TECH
# --------------------------------------------------
# Chunk 319:
# - Electronics & Communication Engineering (Artiﬁcial Intelligence & Cybernetics)
# B
# --------------------------------------------------
# Chunk 320:
# TECH
# --------------------------------------------------
# Chunk 321:
# - Electronics and Communication Engineering (Embedded Systems)
# B
# --------------------------------------------------
# Chunk 322:
# TECH
# --------------------------------------------------
# Chunk 323:
# - Electronics and Communication Engineering (VLSI)
# B
# --------------------------------------------------
# Chunk 324:
# TECH
# --------------------------------------------------
# Chunk 325:
# - Electronics and Computer Engineering
# B
# --------------------------------------------------
# Chunk 326:
# TECH
# --------------------------------------------------
# Chunk 327:
# - Electronics Engineering (VLSI Design and Technology)
# B
# --------------------------------------------------
# Chunk 328:
# TECH
# --------------------------------------------------
# Chunk 329:
# - Information Technology
# B
# --------------------------------------------------
# Chunk 330:
# TECH
# --------------------------------------------------
# Chunk 331:
# - Mechanical Engineering
# B
# --------------------------------------------------
# Chunk 332:
# TECH
# --------------------------------------------------
# Chunk 333:
# - Mechanical Engineering (Automotive Design)
# B
# --------------------------------------------------
# Chunk 334:
# TECH
# --------------------------------------------------
# Chunk 335:
# - Mechanical Engineering (Electric Vehicles)
# B
# --------------------------------------------------
# Chunk 336:
# TECH
# --------------------------------------------------
# Chunk 337:
# - Mechanical Engineering (Manufacturing Engineering)
# B
# --------------------------------------------------
# Chunk 338:
# TECH
# --------------------------------------------------
# Chunk 339:
# - Mechanical Engineering (Artiﬁcial Intelligence & Robotics)
# B
# --------------------------------------------------
# Chunk 340:
# TECH
# --------------------------------------------------
# Chunk 341:
# - Mechanical Engineering (Robotics)
# B
# --------------------------------------------------
# Chunk 342:
# TECH
# --------------------------------------------------
# Chunk 343:
# - Mechatronics and Automation
# (*after concession)Group - B
# Group - A
# Fee Stucture :
# Tuition Fees (Per Annum)
# Caution Deposit (Refundable) (One time payment)
# Total Fees to be paid for the ﬁrst yearINR 1,95,000*
# INR 3,000
# INR 1,98,000(*after concession)Fee Stucture :
# Tuition Fees (Per Annum)
# Caution Deposit (Refundable) (One time payment)
# Total Fees to be paid for the ﬁrst yearINR 1,73,000*
# INR 3,000
# INR 1,76,00012
# --------------------------------------------------
# Chunk 344:
# Fee Structure
# 121
# 2
# 3
# Group - BOnline withdraw / Submit in person
# Necessary form for withdrawal / Clearances should be obtained to enable withdrawal
# --------------------------------------------------
# Chunk 345:
# Date of Application for withdrawal is on the date of submitting clearance form
# --------------------------------------------------
# Chunk 346:
# (*)Includes any kind of leave / absent to the class | *GST if any applicable will be deducted in addition
# Note: The policy announced by AICTE / UGC, will be adopted, as and when announced
# --------------------------------------------------
# Chunk 347:
# 13
# --------------------------------------------------
# Chunk 348:
# Withdrawal Procedure
# 14
# --------------------------------------------------
# Chunk 349:
# Refund Policy
# ConditionsSl
# --------------------------------------------------
# Chunk 350:
# No
# --------------------------------------------------
# Chunk 351:
# For Not Eligible Candidate
# (Either fail or Less than 60% in PCM / PCBRs
# --------------------------------------------------
# Chunk 352:
# 1000/- +GST 18% will be
# deducted = Total: Rs 1,180/-250$ + GST 18% (45$) will be
# deducted = Total: 295$
# 2For withdraw request *received before the
# commencement of the programme
# (Orientation / last date of admission /
# Classes whichever is earlier)Rs 1000/- +GST 18% will be
# deducted = Total: Rs 1,180/-1000 $ + GST 18% (180$) will
# be deducted = Total: 1,180 $
# 3For Withdraw request *received within 25
# days from the commencement of the
# programme (Orientation / last date of
# admission / Classes whichever is earlier)10% of the academic fees will be
# deducted and balance amount
# will be refunded2000 $ will be deducted*
# 4For Withdraw request *received after 25
# days within 40 days from the commencement
# of the programme (Orientation / last date of
# admission / Classes whichever is earlier)20% of the academic fees will be
# deducted and balance amount
# will be refunded3000 $ will be deducted*
# 5For Withdraw request *received after 40
# days from the commencement of the
# programme (Orientation / last date of
# admission / Classes whichever is earlier)Only caution deposit will be
# refunded
# --------------------------------------------------
# Chunk 353:
# Only caution deposit will be
# refunded
# --------------------------------------------------
# Chunk 354:
# *Refund Rule
# (Normal Category)Refund Rule
# (NRI / Foreign Category)
# 1
# 13 Every attempt has been done by the management and other administrative boards to assure that every student ﬁnds VIT a very
# lively, fun and resourceful community to employ their erudite years
# --------------------------------------------------
# Chunk 355:
# Conscious of the inﬂuence these active years can have on the minds of
# the expectation of our nation and the globe, VIT endeavours to promote, introduce and expand any and all ventures to shape their minds
# --------------------------------------------------
# Chunk 356:
# By bringing clubs, chapters and college festivals, students are not simply revealed to a competitive environment inside the university but also
# with reputed universities and colleges in and around the country
# --------------------------------------------------
# Chunk 357:
# A home away from home, the hostels at VIT is more than four walls and a roof
# --------------------------------------------------
# Chunk 358:
# They have been designed to provide a comfortable,
# safe, inclusive and secure living even as they provide opportunities to form lasting friendships and ease the transition from home to college
# --------------------------------------------------
# Chunk 359:
# Residential staﬀ is always available to support the students from diﬀerent backgrounds to promote community
# --------------------------------------------------
# Chunk 360:
# Living on campus provides
# students with opportunities to:
# Develop stronger interpersonal and communication skills
# Establish relationships with faculty and staﬀ membersConnect with a diverse population of people
# Engage in campus leadership, organizations and activities
# 15 Campus life
# 16
# --------------------------------------------------
# Chunk 361:
# HostelsRefer the link below for the respective campus life
# VIT - Vellore VIT - Chennai VIT - AP VIT - Bhopal
# Refer the link below for the respective hostels
# VIT - Vellore VIT - Chennai VIT - AP VIT - Bhopal
# 14Last date for Receipt of the Application  : March 31, 2024 (Tentative)
# VITEEE      : April 19 - 30, 2024 (Tentative)
# (Number of days will vary for test cities)
# Result Declaration    : 3rd May, 2024 (Tentatively)
# Counselling     : To be announced
# Last date of Admission    : 7th July, 2024
#  VIT gives immense emphasis on maintaining a ragging free campus
# --------------------------------------------------
# Chunk 362:
# Anti-Ragging Committee is constituted with Director,
# Students’ Welfare as Chairperson, Assistant Directors, Students’ Welfare as Members and nominated Faculty members from each
# school as Coordinators
# --------------------------------------------------
# Chunk 363:
# Along with the Coordinators from each school, there is a team of squad members that comprises of faculty
# as well as staﬀ members
# --------------------------------------------------
# Chunk 364:
# If any student has any grievance in the nature of ragging, including any kind of harassment, the same can be brought to
# the notice of the Chairperson or any of the Committee Members from various schools, for necessary action and redressal
# --------------------------------------------------
# Chunk 365:
# 17
# --------------------------------------------------
# Chunk 366:
# Anti ragging committee
# 18
# --------------------------------------------------
# Chunk 367:
# Important Dates17
# --------------------------------------------------
# Chunk 368:
# 1
# --------------------------------------------------
# Chunk 369:
# 17
# --------------------------------------------------
# Chunk 370:
# 2
# --------------------------------------------------
# Chunk 371:
# 15vellore_vit  vellore-institute-of-technology   vituniversity  vit_univDirector (UG Admission)
# Vellore Institute of Technology
# Vellore 632 014, Tamilnadu, India
# --------------------------------------------------
# Chunk 372:
# Phone No
# --------------------------------------------------
# Chunk 373:
# :  044 4627 7555
# Email Address : ugadmission@vit
# --------------------------------------------------
# Chunk 374:
# ac
# --------------------------------------------------
# Chunk 375:
# in
# Website : www
# --------------------------------------------------
# Chunk 376:
# vit
# --------------------------------------------------
# Chunk 377:
# ac
# --------------------------------------------------
# Chunk 378:
# in VIT KOTA Information Centre
# 117, Near Nucleus Coaching,
# Old Rajiv Gandhi Nagar,
# Kota (Rajasthan) 324005
# Contact No
# --------------------------------------------------
# Chunk 379:
# : 9782376476, 7690074787
# Email: aadilnaki
# --------------------------------------------------
# Chunk 380:
# pathan@vit
# --------------------------------------------------
# Chunk 381:
# ac
# --------------------------------------------------
# Chunk 382:
# in
# Website : www
# --------------------------------------------------
# Chunk 383:
# vit
# --------------------------------------------------
# Chunk 384:
# ac
# --------------------------------------------------
# Chunk 385:
# inAccreditation & Ranking
# Placement (2023 Graduated Batch)
# For More Details
# 16Legal Jurisdiction : All suits and actions arising out of or relating to VIT shall be instituted within the Jurisdiction of courts at Vellore, Tamilnadu only
# --------------------------------------------------
# Chunk 386:
# 947
# No
# --------------------------------------------------
# Chunk 387:
# of
# Companies4,493
# No
# --------------------------------------------------
# Chunk 388:
# of Super
# Dream Oﬀers
# 3,540
# 14,565No of
# Dream Oﬀers6,532
# No
# --------------------------------------------------
# Chunk 389:
# of
# Regular Oﬀers
# Overall
# Oﬀers1
# --------------------------------------------------
# Chunk 390:
# 02 Cr
# --------------------------------------------------
# Chunk 391:
# Highest
# Package (Per Annum)
# Includes Internships & Placements (10LPA & Above)
# Accredited with the highest
# grade A++ by NAAC
# Ranked #11
# Best Engineering Institution
# of IndiaRanked #163 in Asia by
# QS World University
# Ranking - Asia, 2024
# --------------------------------------------------
# Chunk 392:
# About VIT
# 17
# --------------------------------------------------

# %%
# prompt: An error occurred while reading the PDF: [Errno 22] Invalid argument

# Mount Google Drive to access files
from google.colab import drive
drive.mount('/content/drive')

# Make sure the PDF path points to the correct location in your Google Drive
# For example, if VITEEE-2024-information-brochure.pdf is in the root of My Drive:
# pdf_path = "/content/drive/My Drive/VITEEE-2024-information-brochure.pdf"
# If it's in a subfolder, adjust the path accordingly
# e.g., pdf_path = "/content/drive/My Drive/MyFolder/VITEEE-2024-information-brochure.pdf"

# Replace with the actual path to your PDF file in Google Drive
pdf_path = "/content/drive/My Drive/VITEEE-2024-information-brochure.pdf" # @param {type:"string"}
